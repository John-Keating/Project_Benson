# %% [markdown]
# ## Getting Turnstile Data

# %%
import pandas as pd

df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_150912.txt')

# %%
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/05/2015
# 1        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/05/2015
# 2        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/05/2015
# 3        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/05/2015
# 4        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/05/2015
# 5        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/05/2015
# 6        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/06/2015
# 7        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/06/2015
# 8        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/06/2015
# 9        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/06/2015
# 10       A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  09/06/2015
# ...

# %%
## Takes a list of dates and converts them into URL strings that then read the data as pandas dataframes
## the list must be of 6 character list of strings


def get_turnstiles(dates):
    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_'
    extension = '.txt'
    url_list = []
    
    for date in dates:
        url_list.append(url + date + extension)
        
    for
